# %% [markdown]
# # score prediction model

# %%
# %pip install pandas numpy scikit-learn matplotlib

# %%
import pandas as pd 
data = pd.read_csv("student_performance_updated_1000.csv")
data.head(10)

# %%
print("Columns:", data.columns.tolist())

# %%
data.info()

# %%
data.isnull().sum()

# %%
data.dtypes

# %%
data.describe()
# data['Study Hours'].plot(kind="box")

# %% [markdown]
# I understood that dataset is not complete so we have to impute the data aur delete rows {only in the case when identifier haning the missing value}

# %%
print("ckeck")
# Out:
# ckeck

# %%
S
